# %% [markdown]
# ## Week 9 Exercise
# Made by: Grieving Banana
#
#
# ### Creating the data files: kennels_and_dogs.txt and registrations.txt

# %%
import random


names = ["BELLA","MOLLY", "LUNA","MILLE","CHARLIE","BALDER","MAX","BUSTER"]
breed = ["Labrador Retriever", "German Shepherd", "Golden Retriever", "French Bulldog", "Bulldog", "Beagle", "Poodle", "Rottweiler", "German Shorthaired Pointer", "Yorkshire Terrier"]

kennels = ["Kennel Juni's", "Dansk Kennel Klub", "Kennel Vestegnen", "Nanner's Hundecenter"]

def create_list(number):
    dogs = []
    
    #adding the kennels as the first 4 elements
    for name in kennels:
        kennel = {"name": name}
        dogs.append(kennel)
    
    #adding the dogs
    for i in range(number):
        dog = {"name": random.choice(names), "breed": random.choice(breed)}
        dogs.append(dog)
    
    return dogs

dogs = create_list(100)
print(dogs)
# Out:
# [{'name': "Kennel Juni's"}, {'name': 'Dansk Kennel Klub'}, {'name': 'Kennel Vestegnen'}, {'name': "Nanner's Hundecenter"}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'BUSTER', 'breed': 'Labrador Retriever'}, {'name': 'MAX', 'breed': 'Yorkshire Terrier'}, {'name': 'MAX', 'breed': 'German Shepherd'}, {'name': 'CHARLIE', 'breed': 'German Shepherd'}, {'name': 'CHARLIE', 'breed': 'German Shepherd'}, {'name': 'LUNA', 'breed': 'Labrador Retriever'}, {'name': 'BALDER', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Bulldog'}, {'name': 'BALDER', 'breed': 'Rottweiler'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'LUNA', 'breed': 'Rottweiler'}, {'name': 'CHARLIE', 'breed': 'Yorkshire Terrier'}, {'name': 'BUSTER', 'breed': 'French Bulldog'}, {'name': 'CHARLIE', 'breed': 'Rottweiler'}, {'name': 'BUSTER', 'breed': 'French Bulldog'}, {'name': 'CHARLIE', 'breed': 'Bulldog'}, {'name': 'LUNA', 'breed': 'Rottweiler'}, {'name': 'CHARLIE', 'breed': 'Yorkshire Terrier'}, {'name': 'CHARLIE', 'breed': 'Rottweiler'}, {'name': 'MOLLY', 'breed': 'Golden Retriever'}, {'name': 'MAX', 'breed': 'Beagle'}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'MILLE', 'breed': 'Golden Retriever'}, {'name': 'MILLE', 'breed': 'Rottweiler'}, {'name': 'CHARLIE', 'breed': 'Rottweiler'}, {'name': 'BUSTER', 'breed': 'Beagle'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'LUNA', 'breed': 'German Shepherd'}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'MAX', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'BALDER', 'breed': 'Poodle'}, {'name': 'CHARLIE', 'breed': 'German Shorthaired Pointer'}, {'name': 'BELLA', 'breed': 'Golden Retriever'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'MOLLY', 'breed': 'Labrador Retriever'}, {'name': 'BELLA', 'breed': 'Poodle'}, {'name': 'LUNA', 'breed': 'German Shorthaired Pointer'}, {'name': 'LUNA', 'breed': 'Rottweiler'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'LUNA', 'breed': 'Poodle'}, {'name': 'BELLA', 'breed': 'Poodle'}, {'name': 'BUSTER', 'breed': 'Poodle'}, {'name': 'BALDER', 'breed': 'Yorkshire Terrier'}, {'name': 'BELLA', 'breed': 'Bulldog'}, {'name': 'BUSTER', 'breed': 'German Shepherd'}, {'name': 'LUNA', 'breed': 'Rottweiler'}, {'name': 'BELLA', 'breed': 'Bulldog'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'BUSTER', 'breed': 'Labrador Retriever'}, {'name': 'BELLA', 'breed': 'Labrador Retriever'}, {'name': 'BELLA', 'breed': 'German Shorthaired Pointer'}, {'name': 'MOLLY', 'breed': 'German Shepherd'}, {'name': 'LUNA', 'breed': 'Labrador Retriever'}, {'name': 'BALDER', 'breed': 'Golden Retriever'}, {'name': 'BUSTER', 'breed': 'Poodle'}, {'name': 'CHARLIE', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Rottweiler'}, {'name': 'BALDER', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'Golden Retriever'}, {'name': 'BUSTER', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'MAX', 'breed': 'Beagle'}, {'name': 'CHARLIE', 'breed': 'Bulldog'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'BALDER', 'breed': 'Yorkshire Terrier'}, {'name': 'BALDER', 'breed': 'Poodle'}, {'name': 'MAX', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'Beagle'}, {'name': 'MOLLY', 'breed': 'German Shorthaired Pointer'}, {'name': 'BUSTER', 'breed': 'Yorkshire Terrier'}, {'name': 'MILLE', 'breed': 'Labrador Retriever'}, {'name': 'LUNA', 'breed': 'German Shorthaired Pointer'}, {'name': 'MAX', 'breed': 'French Bulldog'}, {'name': 'MILLE', 'breed': 'German Shepherd'}, {'name': 'LUNA', 'breed': 'Poodle'}, {'name': 'MILLE', 'breed': 'French Bulldog'}, {'name': 'CHARLIE', 'breed': 'German Shorthaired Pointer'}, {'name': 'MAX', 'breed': 'Bulldog'}, {'name': 'MOLLY', 'breed': 'Beagle'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'BUSTER', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'CHARLIE', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'German S ...

# %%
kennel_numbers = []
dog_numbers = []

#Generating a list with ID's from 4-103(the dogs) and a list of random selection of the kennels
for i in range(4,104):
    no_kennel = random.randint(0, 3)
    kennel_numbers.append(no_kennel)
    dog_numbers.append(i)
    
registrations = list(zip(kennel_numbers, dog_numbers)) 
print(registrations)
# Out:
# [(2, 4), (0, 5), (1, 6), (3, 7), (2, 8), (3, 9), (1, 10), (3, 11), (2, 12), (2, 13), (2, 14), (2, 15), (0, 16), (1, 17), (1, 18), (0, 19), (0, 20), (3, 21), (0, 22), (0, 23), (0, 24), (2, 25), (1, 26), (3, 27), (0, 28), (2, 29), (1, 30), (1, 31), (0, 32), (3, 33), (0, 34), (2, 35), (2, 36), (1, 37), (3, 38), (0, 39), (3, 40), (0, 41), (3, 42), (3, 43), (1, 44), (0, 45), (3, 46), (3, 47), (2, 48), (3, 49), (0, 50), (0, 51), (2, 52), (0, 53), (0, 54), (3, 55), (2, 56), (2, 57), (1, 58), (1, 59), (3, 60), (2, 61), (3, 62), (0, 63), (1, 64), (2, 65), (1, 66), (3, 67), (3, 68), (3, 69), (3, 70), (1, 71), (0, 72), (0, 73), (1, 74), (3, 75), (3, 76), (3, 77), (2, 78), (3, 79), (2, 80), (3, 81), (0, 82), (3, 83), (0, 84), (1, 85), (3, 86), (2, 87), (3, 88), (3, 89), (1, 90), (0, 91), (3, 92), (1, 93), (1, 94), (0, 95), (3, 96), (1, 97), (1, 98), (3, 99), (1, 100), (0, 101), (0, 102), (0, 103)]

# %%
with open("registrations.txt","w") as file:
        file.write(str(registrations))

with open("kennels_and_dogs.txt","w") as file:
          file.write(str(dogs))

# %% [markdown]
# ### Exercise 1 - Graphs
#
# A. Read the list of dictionaries of dogs and kennels and the list of registrations from the textfiles: kennels_and_dogs.txt and registrations.txt
#
# Hint: import ast

# %%
import ast

with open('kennels_and_dogs.txt') as f:
    kennels_and_dogs = ast.literal_eval(f.read())

with open('registrations.txt') as f:
    registrations = ast.literal_eval(f.read())
    
print (kennels_and_dogs[:5])
# Out:
# [{'name': "Kennel Juni's"}, {'name': 'Dansk Kennel Klub'}, {'name': 'Kennel Vestegnen'}, {'name': "Nanner's Hundecenter"}, {'name': 'LUNA', 'breed': 'French Bulldog'}]

# %% [markdown]
# B. Make a graph from the two lists and draw it
#
# Hint: install pygraphviz (with pip or conda)

# %%
from networkx.drawing.nx_agraph import graphviz_layout, write_dot
import matplotlib.pyplot as plt
import pygraphviz
import networkx as nx

def create_graph():
    graph = nx.DiGraph() 
    graph.clear()
    
    for idx, info in enumerate(kennels_and_dogs):
        graph.add_node(idx, node=info)
    
    graph.add_edges_from(registrations)

    return graph

def draw_graph(graph):
    nx.draw(graph, pos=graphviz_layout(graph),
            node_size=30, width=.05, cmap=plt.cm.Blues, 
            with_labels=True, node_color=range(len(graph)))

    
graph = create_graph()
print(nx.info(graph))
draw_graph(graph)
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 104
# Number of edges: 100
# Average in degree:   0.9615
# Average out degree:   0.9615

# %% [markdown]
# ## Exercise 2
#
# A. Which kennel has the most dogs registered?

# %%
import numpy as np

node_array = np.array([graph.degree(n) for n in graph.nodes()])
max = node_array.max()
max_idx = np.argmax(node_array)
print('Number of dogs: ' + str(max))
print('Kennel index: ' + str(max_idx))

print('The kennel with the most dogs is: ' + graph.nodes[max_idx]['node']['name'])
# Out:
# Number of dogs: 32
# Kennel index: 3
# The kennel with the most dogs is: Nanner's Hundecenter

# %% [markdown]
# B. Get a list of all the dogs registered at this kennel

# %%
dog_edges = graph.edges(max_idx)

result = []

for edge in dog_edges:
    result.append(graph.nodes[edge[1]]['node'])

print(result)
# Out:
# [{'name': 'MAX', 'breed': 'German Shepherd'}, {'name': 'CHARLIE', 'breed': 'German Shepherd'}, {'name': 'BALDER', 'breed': 'Bulldog'}, {'name': 'LUNA', 'breed': 'Rottweiler'}, {'name': 'MILLE', 'breed': 'Golden Retriever'}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'German Shorthaired Pointer'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'BELLA', 'breed': 'Poodle'}, {'name': 'LUNA', 'breed': 'German Shorthaired Pointer'}, {'name': 'LUNA', 'breed': 'Poodle'}, {'name': 'BELLA', 'breed': 'Poodle'}, {'name': 'BALDER', 'breed': 'Yorkshire Terrier'}, {'name': 'BUSTER', 'breed': 'Labrador Retriever'}, {'name': 'BALDER', 'breed': 'Golden Retriever'}, {'name': 'CHARLIE', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'MAX', 'breed': 'Beagle'}, {'name': 'CHARLIE', 'breed': 'Bulldog'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'MOLLY', 'breed': 'German Shorthaired Pointer'}, {'name': 'BUSTER', 'breed': 'Yorkshire Terrier'}, {'name': 'MILLE', 'breed': 'Labrador Retriever'}, {'name': 'MAX', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'Poodle'}, {'name': 'CHARLIE', 'breed': 'German Shorthaired Pointer'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'CHARLIE', 'breed': 'French Bulldog'}, {'name': 'BUSTER', 'breed': 'Bulldog'}, {'name': 'BALDER', 'breed': 'Rottweiler'}, {'name': 'MAX', 'breed': 'Labrador Retriever'}]

# %% [markdown]
# # 3. exercise
#
# Make a function and use selenium to find the breed from this website https://www.petfinder.com/dog-breeds/ and prints the description.
#
# Using selenium: Go into the website - enter a breed from the list (using keys) - and click to retrieve the description

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

names= []
breeds = []

for dog in result:
    names.append(dog["name"])
    breeds.append(dog["breed"])

print (breeds)

def get_info(breed):
    browser = webdriver.Chrome('./chromedriver')
    browser.get('https://www.petfinder.com/dog-breeds/')
    
    browser.find_element_by_xpath("/html/body/pf-app/div[3]/div/div/div[1]/div/div[1]/div/div/div[3]/div[1]/input").send_keys(breed)
    time.sleep(4)
    browser.find_element_by_link_text(breed).click()

    text = browser.find_element_by_xpath('/html/body/pf-app/div[3]/div/div/div[1]/div/div[1]/div/div[1]/div[3]/div[2]/div[1]/p')

    return text.text

print(get_info(breeds[random.randint(0,10)]))
# Out:
# ['German Shepherd', 'German Shepherd', 'Bulldog', 'Rottweiler', 'Golden Retriever', 'Bulldog', 'German Shorthaired Pointer', 'French Bulldog', 'Poodle', 'German Shorthaired Pointer', 'Poodle', 'Poodle', 'Yorkshire Terrier', 'Labrador Retriever', 'Golden Retriever', 'Bulldog', 'Poodle', 'Beagle', 'Bulldog', 'Rottweiler', 'German Shorthaired Pointer', 'Yorkshire Terrier', 'Labrador Retriever', 'French Bulldog', 'Poodle', 'German Shorthaired Pointer', 'French Bulldog', 'French Bulldog', 'French Bulldog', 'Bulldog', 'Rottweiler', 'Labrador Retriever']
# Frenchies have a low center of gravity, wide body, heavy bone, muscular build, and large, square head with soft loose skin forming wrinkles about the head and shoulders. Entertaining home companions, these lapdogs are alert, with a curious expression, aided by bar ears, and unrestrained and free movement.
