# %% [markdown]
# ### Exercise 1
#
# Use webscrabing to retrieve the table data from https://www.worldometers.info/coronavirus/ and create a pandas DataFrame to show the data.

# %%
import bs4
import requests
import pandas as pd
import numpy as np

r = requests.get('https://www.worldometers.info/coronavirus/')
r.raise_for_status()
soup = bs4.BeautifulSoup(r.text, 'html.parser')

columns = []
data = []

for header in soup.find_all('th'):
    columns.append(header.getText()) 
    
for table_data in soup.find_all('td'):
    data.append(table_data.getText())
    

cities = np.reshape(data,(int(len(data)/9),9))

df = pd.DataFrame(data=cities, columns=columns[0:9])

print(df)
# Out:
#     Country,Other TotalCases NewCases                            TotalDeaths  \
# 0           China     81,008      +41  3,255
# 1           Italy     47,021           4,032
# 2           Spain     24,926   +3,355  1,326
# 3         Germany     20,705     +857     72
# 4            Iran     20,610     +966  1,556
# ..            ...        ...      ...                                    ...
# 370  Sint Maarten          1
# 371       Somalia          1
# 372      Eswatini          1
# 373      Zimbabwe          1       +1
# 374        Total:    275,557   30,663                                 11,380
#
#     NewDeaths TotalRecovered ActiveCases Serious,Critical Tot Cases/1M pop
# 0          +7         71,740       6,013            1,927               56
# 1                      5,129      37,860            2,655              778
# 2        +233          2,125      21,475              939              533
# 3          +4            209      20,424                2              247
# 4        +123          7,635      11,419                               245
# ..        ...            ...         ...              ...              ...
# 370                                    1                                23
# 371                                    1                              0.06
# 372                                    1                               0.9
# 373                                    1                              0.07
# 374     1,352         90,983     173,194            8,120             35.4
#
# [375 rows x 9 columns]

# %% [markdown]
# Clean Up the data by removing the '+' symbol from colums "NewDeaths" and "NewCases"
#
# HINT!! Be VERY observant in reguards to the amount of whitespace

# %%
filter = df["NewCases"] != " "
dfNew = df[filter]

dfNew["NewCases"] = dfNew["NewCases"].str.slice(2,-1)

dfNew["NewDeaths"] = dfNew["NewDeaths"].str.slice(1,-1)

dfNew.replace(" ", "0", inplace=True)
dfNew.replace("", "0", inplace=True)

dfNew.head(30)
# Out:
#        Country,Other TotalCases NewCases  \
# 0              China     81,008        0
# 1              Italy     47,021        0
# 2              Spain     24,926      ,35
# 3            Germany     20,705        5
# 4               Iran     20,610        6
# 5                USA     19,775        9
# 6             France     12,612        0
# 7           S. Korea      8,799        4
# 8        Switzerland      6,186        7
# 9                 UK      3,983        0
# 10       Netherlands      2,994        0
# 11           Belgium      2,815        5
# 12           Austria      2,719        0
# 13            Norway      1,997        0
# 14            Sweden      1,674        0
# 15           Denmark      1,326        0
# 16          Portugal      1,280        6
# 17          Malaysia      1,183        5
# 18            Canada      1,087        0
# 19         Australia      1,068        4
# 20             Japan      1,007        0
# 21            Brazil        978        0
# 22           Czechia        925        0
# 23            Israel        883        7
# 24  Diamond Princess        712        0
# 25           Ireland        683        0
# 26            Turkey        670        0
# 27        Luxembourg        670        8
# 28          Pakistan        625        2
# 29           Finland        512        0
#
#                               TotalDeaths NewDeaths TotalRecovered  \
# 0   3,255                                         0         71,740
# 1   4,032                                         0          5,129
# 2   1,326                                        23          2,125
# 3      72                                         0            209
# 4   1,556                                        12          7,635
# 5     276                                         2            147
# 6     450                                         0          1,587
# 7     102                                         0          2,612
# 8      58                                         0             15
# 9     177                                         0             65
# 10    106                                         0              2
# 11     67                                         3            263
# 12      7                                         0              9
# 13      7                                         0              1
# 14     17                                         0             16
# 15     13                                         0              1
# 16     12                                         0              5
# 17      4                                         0            114
# 18     12                                         0             14
# 19      7                                         0             46
# 20     35                                         0            215
# 21     11                                         0              2
# 22                                      0         0              4
# 23      1                                         0             36
# 24      8                                         0            567
# 25      3                                         0              5
# 26      9                                         0              0
# 27      8                                         0              6
# 28      3                                         0             13
# 29                                      0         0             10
#
#    ActiveCases Serious,Critical Tot Cases/1M pop
# 0        6,013            1,927               56
# 1       37,860            2,655              778
# 2       21,475              939              533
# 3       20,424                2              247
# 4       11,419                0              245
# 5       19,352               64               60
# 6       10,575            1,297              193
# 7        6,085               59              172
# 8        6,113              141              715
# 9        3,741               20               59
# 10       2,886              210              175
# 11       2,485              288              243
# 12       2,703               15              302
# 13       1,989               27              368
# 14       1,641               69              166
# 15       1,312               42              229
# 16       1,263               26              126
# 17       1,065               26               37
# 18       1,061                1               29
# 19       1,015                2               42
# 20         757               50                8
# 21         965               18                5
# 22         921                6               86
# 23         846               15              102
# 24         137               15                0
# 25         675                6              138
# 26         661                0                8
# 27         656                1            1,070
# 28         609                0                3
# 29         502                2               92

# %% [markdown]
# Create a bar plot showing the number of TotalCases in each country (remember to leave out the total row)
#
# Hint! the numbers should be stripped from spacing and thousand separators should be removed

# %%
import matplotlib.pyplot as plt
import numpy as np

countries = list(dfNew['Country,Other'])
cases = list(dfNew['TotalCases'])

cases = [int(i.strip().replace(",","")) for i in cases] 

# Removing the total row in the end
countries.pop()
cases.pop()

plt.figure(figsize=(20,10))
plt.bar(countries, cases, width=0.8, align='center',alpha=0.7)
plt.xticks(rotation='vertical')
plt.tick_params(axis='x', which='major', labelsize=10)
plt.tight_layout()

plt.show()
